# %% [markdown]
# #
# # 이전 Lipid Profile 추가하고 정상 / 비정상

# %%
##
import numpy as np
import pandas as pd
from import_data import *
import torch
import torch.optim as optim
import torch.nn as nn
from network import DNN, DNN_v1, DNN_cat
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
from utils import EarlyStopping, KFOLD_GCN
# from matplotlib import pyplot as plt
# from config import args
from collections import Counter



if torch.cuda.is_available():
    print("Let's go CUDA!!!!!")
    cuda = torch.device('cuda')
else:
    print("No CUDA,,,")
    cuda = torch.device('cpu')
    
    
np.random.seed(777)
kfold = 5
# y_value = args.y

data1, data2, data3, data4 = DATA_PREPROCESS_SH_v2()
# Out:
# /home/kicarus/anaconda3/lib/python3.6/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# /home/kicarus/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (5,6,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# No CUDA,,,

# %%
ckpath = 'checkpoint_wlipid_bool.pt'

# %%
xdata, ydata = xysplit(data2)
xdata = np.array(xdata)
ydata = np.array(ydata)

# %%
# data, xdata, ydata = DATA_PREPROCESS_SH(log=False)
xdata = NORMALIZATION(xdata, 'standard')
ydata = CATEGORIZATION_v2(ydata)
for i in range(len(ydata[0])):
    print(Counter(ydata[:, i]))


def _ychoice(y):
    this = np.transpose(np.concatenate((np.transpose(xdata), [ydata[:, y]]), axis=0))
    this = np.array(this)
    # this = this.astype(float)
    np.random.shuffle(this)
    return this
# data.to_csv('kky1.csv', index=None)





# def _TData(train, y):
#     """
#      0~14 features, 15~18 labels
#     """
#     til = size[1] - 4
#     train_dataset = TensorDataset(torch.Tensor(train[:, :til]).to(cuda),
#                                   torch.Tensor(train[:, y]).to(cuda))
#
#     return train_dataset

def _TData_v2(train):
    train_dataset = TensorDataset(torch.Tensor(train[:, :-1]).to(cuda),
                                  torch.LongTensor(train[:, -1]).to(cuda))

    return train_dataset



def Parameters(net):
    # criterion = nn.CrossEntropyLoss()
    criterion = nn.MSELoss(reduction='mean')
    # optimizer = optim.SGD(net.parameters(), lr=0.000001)
    optimizer = optim.Adam(net.parameters(), lr=0.01)

    return criterion, optimizer

def Parameters_cat(net):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(net.parameters(), lr=0.001)

    return criterion, optimizer
# Out:
# Counter({0: 3061, 1: 2321})
# Counter({0: 4831, 1: 551})
# Counter({1: 3048, 0: 2334})
# Counter({0: 3743, 1: 1639})

# %%
def Learning_all(train_loader, val_loader, nodes, num, patience=10, num_classes=None):
    """
        train_loader: 학습시킬 데이터셋 (DataLoader 형식)
        val_loader: 평가할 데이터셋 (DataLoader 형식)
        num: Epochs

    """
    net = DNN_cat(xdata.shape[1], num_classes, nodes)
    criterion, optimizer = Parameters_cat(net)
    net.to(cuda)

    """Early Stopping Template"""
    for epoch in range(num):
        torch.cuda.empty_cache()
        if epoch == 0:
            early_stopping = EarlyStopping(patience=patience, path=ckpath, verbose=False)
        else:
            early_stopping = EarlyStopping(patience=patience, best_score=best_score, counter=counter, path=ckpath, verbose=False)

        # Training
        net.train()
        running_loss = 0.
        lcnt = 0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)

            outputs = net(inputs)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            lcnt += len(labels)

        # Validation
        net.eval()
        net.to(cuda)

        val_loss = 0
        vcnt = 0
        for i, data in enumerate(val_loader):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)
            outputs = net(inputs)

            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)

            val_loss += loss.item()
            vcnt += len(labels)

        # Template
        best_score, counter, finish = early_stopping(val_loss / vcnt, net)
        # if epoch % 50 == 0:
        #     print('Epoch Now: %d' % epoch)

        if finish:
            break

    net1 = DNN_cat(xdata.shape[1], num_classes, nodes)
    net1.load_state_dict(torch.load(ckpath))
    net1.eval()

    # output save
    val_loss = 0
    correct = 0
    class_correct = list(0. for i in range(num_classes))
    class_total = list(0. for i in range(num_classes))
    precision_c = list(0. for i in range(num_classes))
    precision_t = list(0. for i in range(num_classes))
    label_all = []
    output_all = []
    
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)

            outputs = net1(inputs)
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)
            val_loss += loss.item()

            correct += (predicted == labels).sum().item()

            c = (predicted == labels).squeeze()
            for i in range(len(labels)):
                label = labels[i]
                class_correct[label] += c[i].item()
                class_total[label] += 1

            for i in range(len(predicted)):
                output = predicted[i].item()
                precision_c[output] += c[i].item()
                precision_t[output] += 1
            
            label_all.append(labels)
            output_all.append(outputs)
            
        print('Best Epoch: %5d / Last Validation Loss: %5f / Accuracy: %.3f'
              % (epoch - patience, val_loss / vcnt, 100 * correct / vcnt))

        for cls in range(num_classes):
            if class_total[cls] == 0:
                print('To small dataset for %s' % cls)
            else:
                print('Recall of %5s : %2d %%' % (
                    cls, 100 * class_correct[cls] / class_total[cls]))

        for cls in range(num_classes):
            if precision_t[cls] == 0:
                print('No prediction for %s' % cls)
            else:
                print('Precision of %5s : %2d %%' % (
                    cls, 100 * precision_c[cls] / precision_t[cls]))

    return correct / vcnt, label_all, output_all


def RUN_all(batch_size, kfold, max_epoch, y_value, node_list, patience):
    # Train / Test split
    data = _ychoice(y_value)
    
    num_classes = len(set(data[:, -1]))
    tmp = KFOLD_GCN(data, KFOLD=kfold)
    train = np.vstack(tmp[:-1])
    test = tmp[-1]


    print('\n\n\n가즈아~!~!~!~!~!')
    print('y_value: %2d' % y_value)

    acc_box = []
    for nodes in node_list:

        acc = 0
        print('Nodes: %2d' % nodes)

        kfold_all = KFOLD_GCN(train, kfold)
        for k in range(kfold):
            validation = kfold_all[k]
            training = []
            for exp in range(kfold):
                if exp != k:
                    training.append(kfold_all[exp])
            training = np.vstack(training)

            train_loader = DataLoader(_TData_v2(training), batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(_TData_v2(validation), batch_size=batch_size, shuffle=False)
            acc_all, label_all, output_all = Learning_all(train_loader, val_loader, nodes, max_epoch, patience, num_classes)
            acc += acc_all

        print('Validation Accuracy: %f' % (acc / kfold))
        acc_box.append(acc / kfold)
        
        
    best_node = node_list[acc_box.index(max(acc_box))]
    train_loader = DataLoader(_TData_v2(train), batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(_TData_v2(test), batch_size=batch_size, shuffle=False)
    
    print('')
    print('This is best result')
    print('')
    acc_all, label_all, output_all = Learning_all(train_loader, test_loader, best_node, max_epoch, patience, num_classes)

    print('# of node: %d \nTest Accuracy: %f' %
          (best_node, acc_all))

    return np.hstack([i.numpy() for i in label_all]), np.vstack([i.numpy() for i in output_all])

# %%
batch_size = 128
kfold = 5
max_epoch = 1000
n_list = [6, 9, 12, 15, 18, 21, 24, 27, 30]

# %%
a, b = RUN_all(batch_size, kfold, max_epoch, y_value=-4, node_list=n_list, patience=100)
# Out:
# /home/kicarus/anaconda3/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 가즈아~!~!~!~!~!
# y_value: -4
# Nodes:  6
# Early Stopping Validated
# Best Epoch:    80 / Last Validation Loss: 0.004193 / Accuracy: 75.930
# Recall of     0 : 79 %
# Recall of     1 : 71 %
# Precision of     0 : 78 %
# Precision of     1 : 72 %
# Early Stopping Validated
# Best Epoch:    26 / Last Validation Loss: 0.004111 / Accuracy: 74.767
# Recall of     0 : 79 %
# Recall of     1 : 68 %
# Precision of     0 : 76 %
# Precision of     1 : 71 %
# Early Stopping Validated
# Best Epoch:    18 / Last Validation Loss: 0.004235 / Accuracy: 75.377
# Recall of     0 : 81 %
# Recall of     1 : 67 %
# Precision of     0 : 76 %
# Precision of     1 : 73 %
# Early Stopping Validated
# Best Epoch:    79 / Last Validation Loss: 0.003848 / Accuracy: 78.746
# Recall of     0 : 80 %
# Recall of     1 : 76 %
# Precision of     0 : 81 %
# Precision of     1 : 75 %
# Early Stopping Validated
# Best Epoch:    84 / Last Validation Loss: 0.004042 / Accuracy: 76.450
# Recall of     0 : 83 %
# Recall of     1 : 67 %
# Precision of     0 : 77 %
# Precision of     1 : 75 %
# Validation Accuracy: 0.762542
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    75 / Last Validation Loss: 0.004214 / Accuracy: 75.233
# Recall of     0 : 78 %
# Recall of     1 : 71 %
# Precision of     0 : 78 %
# Precision of     1 : 71 %
# Early Stopping Validated
# Best Epoch:    32 / Last Validation Loss: 0.004127 / Accuracy: 75.000
# Recall of     0 : 78 %
# Recall of     1 : 70 %
# Precision of     0 : 77 %
# Precision of     1 : 71 %
# Early Stopping Validated
# Best Epoch:    25 / Last Validation Loss: 0.004285 / Accuracy: 75.494
# Recall of     0 : 80 %
# Recall of     1 : 68 %
# Precision of     0 : 77 %
# Precision of     1 : 72 %
# Early Stopping Validated
# Best Epoch:    97 / Last Validation Loss: 0.003823 / Accuracy: 77.468
# Recall of     0 : 80 %
# Recall of     1 : 74 %
# Precision of     0 : 80 %
# Precision of     1 : 73 %
# Early Stopping Validated
# Best Epoch:    52 / Last Validation Loss: 0.004086 / Accuracy: 75.986
# Recall of     0 : 81 %
# Recall of     1 : 69 %
# Precision of     0 : 77 %
# Precision of     1 : 73 %
# Validation Accuracy: 0.758361
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    23 / Last Validation Loss: 0.004258 / Accuracy: 74.884
# Recall of     0 : 80 %
# Recall of     1 : 67 %
# Precision of     0 : 76 %
# Precision of     1 : 72 %
# Early Stopping Validated
# Best Epoch:    33 / Last Validation Loss: 0.004117 / Accuracy: 75.349
# Recall of     0 : 79 %
# Recall of     1 : 69 %
# Precision of     0 : 77 %
# Precision of     1 : 72 %
# Early Stopping Validated
# Best Epoch:    13 / Last Validation Loss: 0.004257 / Accuracy: 75.494
# Recall of     0 : 82 %
# Recall of     1 : 66 %
%
# Precision of     1 : 71 %
# Early Stopping Validated
# Best Epoch:    13 / Last Validation Loss: 0.004227 / Accuracy: 75.261
# Recall of     0 : 81 %
# Recall of     1 : 67 %
# Precision of     0 : 76 %
# Precision of     1 : 73 %
# Early Stopping Validated
# Best Epoch:    21 / Last Validation Loss: 0.003779 / Accuracy: 78.049
# Recall of     0 : 80 %
# Recall of     1 : 75 %
# Precision of     0 : 81 %
# Precision of     1 : 74 %
# Early Stopping Validated
# Best Epoch:    21 / Last Validation Loss: 0.004144 / Accuracy: 74.594
# Recall of     0 : 80 %
# Recall of     1 : 67 %
# Precision of     0 : 76 %
# Precision of     1 : 72 %
# Validation Accuracy: 0.757669
#
# This is best result
#
# Early Stopping Validated
# Best Epoch:    85 / Last Validation Loss: 0.004206 / Accuracy: 75.696
# Recall of     0 : 79 %
# Recall of     1 : 70 %
# Precision of     0 : 78 %
# Precision of     1 : 72 %
# # of node: 6
# Test Accuracy: 0.756957

# %%
a1, b1 = RUN_all(batch_size, kfold, max_epoch, y_value=-3, node_list=n_list, patience=100)
# Out:
# 가즈아~!~!~!~!~!
# y_value: -3
# Nodes:  6
# /home/kicarus/anaconda3/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Early Stopping Validated
# Best Epoch:    27 / Last Validation Loss: 0.002835 / Accuracy: 89.767
# Recall of     0 : 99 %
# Recall of     1 :  3 %
# Precision of     0 : 90 %
# Precision of     1 : 50 %
# Early Stopping Validated
# Best Epoch:   116 / Last Validation Loss: 0.002331 / Accuracy: 91.405
# Recall of     0 : 98 %
# Recall of     1 : 32 %
# Precision of     0 : 92 %
# Precision of     1 : 65 %
# Early Stopping Validated
# Best Epoch:    84 / Last Validation Loss: 0.002376 / Accuracy: 91.405
# Recall of     0 : 98 %
# Recall of     1 : 26 %
# Precision of     0 : 92 %
# Precision of     1 : 71 %
# Early Stopping Validated
# Best Epoch:    22 / Last Validation Loss: 0.002681 / Accuracy: 89.663
# Recall of     0 : 99 %
# Recall of     1 :  3 %
# Precision of     0 : 90 %
# Precision of     1 : 42 %
# Early Stopping Validated
# Best Epoch:    78 / Last Validation Loss: 0.002306 / Accuracy: 90.592
# Recall of     0 : 98 %
# Recall of     1 : 17 %
# Precision of     0 : 91 %
# Precision of     1 : 65 %
# Validation Accuracy: 0.905667
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    26 / Last Validation Loss: 0.002827 / Accuracy: 89.302
# Recall of     0 : 99 %
# Recall of     1 :  1 %
# Precision of     0 : 89 %
# Precision of     1 : 16 %
# Early Stopping Validated
# Best Epoch:   111 / Last Validation Loss: 0.002476 / Accuracy: 90.244
# Recall of     0 : 97 %
# Recall of     1 : 27 %
# Precision of     0 : 92 %
# Precision of     1 : 54 %
# Early Stopping Validated
# Best Epoch:    66 / Last Validation Loss: 0.002320 / Accuracy: 91.986
# Recall of     0 : 99 %
# Recall of     1 : 29 %
# Precision of     0 : 92 %
# Precision of     1 : 78 %
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 0.002737 / Accuracy: 89.431
# Recall of     0 : 99 %
# Recall of     1 :  0 %
# Precision of     0 : 89 %
# Precision of     1 :  0 %
# Early Stopping Validated
# Best Epoch:    79 / Last Validation Loss: 0.002325 / Accuracy: 90.360
# Recall of     0 : 98 %
# Recall of     1 : 18 %
# Precision of     0 : 91 %
# Precision of     1 : 59 %
# Validation Accuracy: 0.902646
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 0.002877 / Accuracy: 88.605
# Recall of     0 : 97 %
# Recall of     1 :  9 %
# Precision of     0 : 90 %
# Precision of     0 : 91 %
# Precision of     1 : 56 %
# Validation Accuracy: 0.902648
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 0.002861 / Accuracy: 89.419
# Recall of     0 : 99 %
# Recall of     1 :  4 %
# Precision of     0 : 90 %
# Precision of     1 : 36 %
# Early Stopping Validated
# Best Epoch:    33 / Last Validation Loss: 0.002427 / Accuracy: 90.592
# Recall of     0 : 96 %
# Recall of     1 : 35 %
# Precision of     0 : 92 %
# Precision of     1 : 56 %
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 0.002312 / Accuracy: 91.521
# Recall of     0 : 99 %
# Recall of     1 : 23 %
# Precision of     0 : 91 %
# Precision of     1 : 77 %
# Early Stopping Validated
# Best Epoch:     9 / Last Validation Loss: 0.002718 / Accuracy: 90.012
# Recall of     0 : 99 %
# Recall of     1 :  5 %
# Precision of     0 : 90 %
# Precision of     1 : 62 %
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 0.002323 / Accuracy: 90.708
# Recall of     0 : 98 %
# Recall of     1 : 20 %
# Precision of     0 : 91 %
# Precision of     1 : 64 %
# Validation Accuracy: 0.904505
#
# This is best result
#
# Early Stopping Validated
# Best Epoch:    45 / Last Validation Loss: 0.003011 / Accuracy: 90.260
# Recall of     0 : 98 %
# Recall of     1 : 14 %
# Precision of     0 : 90 %
# Precision of     1 : 61 %
# # of node: 6
# Test Accuracy: 0.902597

# %%
a2, b2 = RUN_all(batch_size, kfold, max_epoch, y_value=-2, node_list=n_list, patience=100)
# Out:
# 가즈아~!~!~!~!~!
# y_value: -2
# Nodes:  6
# /home/kicarus/anaconda3/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 0.003524 / Accuracy: 78.837
# Recall of     0 : 73 %
# Recall of     1 : 82 %
# Precision of     0 : 76 %
# Precision of     1 : 80 %
# Early Stopping Validated
# Best Epoch:    29 / Last Validation Loss: 0.003283 / Accuracy: 81.395
# Recall of     0 : 74 %
# Recall of     1 : 86 %
# Precision of     0 : 81 %
# Precision of     1 : 81 %
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.003527 / Accuracy: 79.443
# Recall of     0 : 78 %
# Recall of     1 : 80 %
# Precision of     0 : 75 %
# Precision of     1 : 82 %
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 0.003241 / Accuracy: 80.510
# Recall of     0 : 76 %
# Recall of     1 : 83 %
# Precision of     0 : 77 %
# Precision of     1 : 82 %
# Early Stopping Validated
# Best Epoch:    15 / Last Validation Loss: 0.003440 / Accuracy: 79.118
# Recall of     0 : 79 %
# Recall of     1 : 79 %
# Precision of     0 : 74 %
# Precision of     1 : 83 %
# Validation Accuracy: 0.798608
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 0.003528 / Accuracy: 80.000
# Recall of     0 : 73 %
# Recall of     1 : 85 %
# Precision of     0 : 79 %
# Precision of     1 : 80 %
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 0.003259 / Accuracy: 81.512
# Recall of     0 : 74 %
# Recall of     1 : 87 %
# Precision of     0 : 81 %
# Precision of     1 : 81 %
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.003290 / Accuracy: 80.742
# Recall of     0 : 78 %
# Recall of     1 : 82 %
# Precision of     0 : 77 %
# Precision of     1 : 83 %
# Early Stopping Validated
# Best Epoch:    13 / Last Validation Loss: 0.003419 / Accuracy: 77.842
# Recall of     0 : 76 %
# Recall of     1 : 78 %
# Precision of     0 : 73 %
# Precision of     1 : 81 %
# Validation Accuracy: 0.801168
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.003510 / Accuracy: 79.535
# Recall of     0 : 73 %
# Recall of     1 : 83 %
# Precision of     0 : 77 %
# Precision of     1 : 80 %
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 0.003209 / Accuracy: 82.791
# Recall of     0 : 76 %
# Recall of     1 : 87 %
# Precision of     0 : 82 %
# Precision of     1 : 82 %
# Early Stopping Validated
# Best Epoch:     7 / Last Validation Loss: 0.003514 / Accuracy: 79.094
# Recall of     0 : 78 %
# Recall of     1 : 79 %
# Precision of     0 : 74 %
# Precision of     1 : 82 %
# Early Stopping Validated
# Best Epoch:    10 / Last Validation Loss: 0.003226 / Accuracy: 81.787
# Recall of     0 : 78 %
# Recall of     1 : 84 %
# Precision of     0 : 79 %
# Precision of     1 : 83 %
# Early Stopping Validated
# Best Epoch:    10 / Last Validation Loss: 0.003349 / Accuracy: 78.538
# Recall of     0 : 76 %
# Recall of     1 : 79 %
# Precision of     0 : 74 %
# Precision of     1 : 81 %
# Validation Accuracy: 0.803489
#
# This is best result
#
# Early Stopping Validated
# Best Epoch:    10 / Last Validation Loss: 0.003342 / Accuracy: 81.058
# Recall of     0 : 77 %
# Recall of     1 : 84 %
# Precision of     0 : 78 %
# Precision of     1 : 82 %
# # of node: 21
# Test Accuracy: 0.810585

# %%
a3, b3 = RUN_all(batch_size, kfold, max_epoch, y_value=-1, node_list=n_list, patience=100)
# Out:
# 가즈아~!~!~!~!~!
# y_value: -1
# Nodes:  6
# /home/kicarus/anaconda3/lib/python3.6/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 0.004226 / Accuracy: 74.767
# Recall of     0 : 85 %
# Recall of     1 : 50 %
# Precision of     0 : 79 %
# Precision of     1 : 60 %
# Early Stopping Validated
# Best Epoch:    16 / Last Validation Loss: 0.003979 / Accuracy: 77.816
# Recall of     0 : 88 %
# Recall of     1 : 54 %
# Precision of     0 : 81 %
# Precision of     1 : 66 %
# Early Stopping Validated
# Best Epoch:   102 / Last Validation Loss: 0.003593 / Accuracy: 80.720
# Recall of     0 : 88 %
# Recall of     1 : 63 %
# Precision of     0 : 84 %
# Precision of     1 : 70 %
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 0.003772 / Accuracy: 78.862
# Recall of     0 : 86 %
# Recall of     1 : 60 %
# Precision of     0 : 83 %
# Precision of     1 : 66 %
# Early Stopping Validated
# Best Epoch:    60 / Last Validation Loss: 0.003873 / Accuracy: 78.538
# Recall of     0 : 88 %
# Recall of     1 : 55 %
# Precision of     0 : 81 %
# Precision of     1 : 68 %
# Validation Accuracy: 0.781408
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    37 / Last Validation Loss: 0.004283 / Accuracy: 75.233
# Recall of     0 : 85 %
# Recall of     1 : 51 %
# Precision of     0 : 80 %
# Precision of     1 : 61 %
# Early Stopping Validated
# Recall of     0 : 86 %
# Recall of     1 : 49 %
# Precision of     0 : 79 %
# Precision of     1 : 61 %
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 0.003996 / Accuracy: 77.352
# Recall of     0 : 86 %
# Recall of     1 : 57 %
# Precision of     0 : 82 %
# Precision of     1 : 64 %
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 0.003563 / Accuracy: 80.488
# Recall of     0 : 88 %
# Recall of     1 : 61 %
# Precision of     0 : 84 %
# Precision of     1 : 70 %
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 0.003768 / Accuracy: 77.003
# Recall of     0 : 85 %
# Recall of     1 : 56 %
# Precision of     0 : 81 %
# Precision of     1 : 63 %
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 0.003808 / Accuracy: 80.162
# Recall of     0 : 90 %
# Recall of     1 : 57 %
# Precision of     0 : 82 %
# Precision of     1 : 72 %
# Validation Accuracy: 0.780011
# Nodes: 21
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.004233 / Accuracy: 75.465
# Recall of     0 : 86 %
# Recall of     1 : 49 %
# Precision of     0 : 79 %
# Precision of     1 : 62 %
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.004095 / Accuracy: 76.423
# Recall of     0 : 87 %
# Recall of     1 : 51 %
# Precision of     0 : 80 %
# Precision of     1 : 63 %
# Early Stopping Validated
# Best Epoch:    23 / Last Validation Loss: 0.003535 / Accuracy: 80.952
# Recall of     0 : 89 %
# Recall of     1 : 62 %
# Precision of     0 : 84 %
# Precision of     1 : 71 %
# Early Stopping Validated
# Best Epoch:    30 / Last Validation Loss: 0.003756 / Accuracy: 78.165
# Recall of     0 : 87 %
# Recall of     1 : 56 %
# Precision of     0 : 82 %
# Precision of     1 : 66 %
# Early Stopping Validated
# Best Epoch:    18 / Last Validation Loss: 0.003810 / Accuracy: 78.770
# Recall of     0 : 89 %
# Recall of     1 : 53 %
# Precision of     0 : 81 %
# Precision of     1 : 70 %
# Validation Accuracy: 0.779551
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 0.004224 / Accuracy: 75.233
# Recall of     0 : 86 %
# Recall of     1 : 49 %
# Precision of     0 : 79 %
# Precision of     1 : 61 %
# Early Stopping Validated
# Best Epoch:    21 / Last Validation Loss: 0.004024 / Accuracy: 78.165
# Recall of     0 : 87 %
# Recall of     1 : 57 %
# Precision of     0 : 82 %
# Precision of     1 : 66 %
# Early Stopping Validated
# Best Epoch:    17 / Last Validation Loss: 0.003585 / Accuracy: 80.604
# Recall of     0 : 88 %
# Recall of     1 : 62 %
# Precision of     0 : 84 %
# Precision of     1 : 70 %
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.003776 / Accuracy: 77.700
# Recall of     0 : 87 %
# Recall of     1 : 55 %
# Precision of     0 : 81 %
# Precision of     1 : 65 %
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.003792 / Accuracy: 78.886
# Recall of     0 : 89 %
# Recall of     1 : 55 %
# Precision of     0 : 81 %
# Precision of     1 : 69 %
# Validation Accuracy: 0.781176
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    25 / Last Validation Loss: 0.004240 / Accuracy: 75.814
# Recall of     0 : 85 %
# Recall of     1 : 53 %
# Precision of     0 : 80 %
# Precision of     1 : 62 %
# Early Stopping Validated
# Best Epoch:     6 / Last Validation Loss: 0.003985 / Accuracy: 77.468
# Recall of     0 : 89 %
# Recall of     1 : 50 %
# Precision of     0 : 80 %
# Precision of     1 : 67 %
# Early Stopping Validated
# Best Epoch:    32 / Last Validation Loss: 0.003591 / Accuracy: 80.604
# Recall of     0 : 88 %
# Recall of     1 : 63 %
# Precision of     0 : 84 %
# Precision of     1 : 70 %
# Early Stopping Validated
# Best Epoch:    23 / Last Validation Loss: 0.003766 / Accuracy: 78.513
# Recall of     0 : 87 %
# Recall of     1 : 58 %
# Precision of     0 : 82 %
# Precision of     1 : 66 %
# Early Stopping Validated
# Best Epoch:    30 / Last Validation Loss: 0.003870 / Accuracy: 78.770
# Recall of     0 : 89 %
# Recall of     1 : 53 %
# Precision of     0 : 81 %
# Precision of     1 : 69 %
# Validation Accuracy: 0.782339
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    13 / Last Validation Loss: 0.004285 / Accuracy: 75.349
# Recall of     0 : 85 %
# Recall of     1 : 51 %
# Precision of     0 : 80 %
# Precision of     1 : 61 %
# Early Stopping Validated
# Best Epoch:     6 / Last Validation Loss: 0.003992 / Accuracy: 77.933
# Recall of     0 : 88 %
# Recall of     1 : 53 %
# Precision of     0 : 81 %
# Precision of     1 : 67 %
# Early Stopping Validated
# Best Epoch:    22 / Last Validation Loss: 0.003601 / Accuracy: 80.256
# Recall of     0 : 87 %
# Recall of     1 : 62 %
# Precision of     0 : 84 %
# Precision of     1 : 69 %
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 0.003769 / Accuracy: 78.165
# Recall of     0 : 87 %
# Recall of     1 : 57 %
# Precision of     0 : 82 %
# Precision of     1 : 66 %
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 0.003841 / Accuracy: 78.770
# Recall of     0 : 90 %
# Recall of     1 : 52 %
# Precision of     0 : 81 %
# Precision of     1 : 70 %
# Validation Accuracy: 0.780944
#
# This is best result
#
# Early Stopping Validated
# Best Epoch:    27 / Last Validation Loss: 0.003942 / Accuracy: 79.201
# Recall of     0 : 87 %
# Recall of     1 : 59 %
# Precision of     0 : 83 %
# Precision of     1 : 68 %
# # of node: 27
# Test Accuracy: 0.792015

# %%
f1 = (a, b)
f2 = (a1, b1)
f3 = (a2, b2)
f4 = (a3, b3)

import pickle

filelist = [f1, f2, f3, f4]
filename = ['TCH', 'TG', 'HDL', 'LDL']

for i in range(4):
    name = filename[i] + '_TF.pkl'
    with open(name, 'wb') as f:
        pickle.dump(filelist[i], f)

# %%
# Out:
# (array([0, 0, 0, ..., 1, 1, 1]), array([[ 0.15514795, -1.8480325 ],
#         [-0.02215788, -0.65983534],
#         [-0.25747016, -0.95961493],
#         ...,
#         [-0.5618443 , -1.2208526 ],
#         [-1.0310642 ,  0.08539528],
#         [-0.49538612, -0.88637155]], dtype=float32))
