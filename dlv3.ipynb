# %% [markdown]
# #
# # 이전 Lipid Profile 없이 R 스퀘어 계산

# %%
"""
    Written on January 9, 2021
    Code by Junmo Kim

    추가내용: 변수추가, R스퀘어 계산

"""

##
import numpy as np
import pandas as pd
from import_data import DATA_PREPROCESS, DATA_PREPROCESS_SH_v2, NORMALIZATION
import torch
import torch.optim as optim
import torch.nn as nn
from network import DNN, DNN_v1
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
from utils import EarlyStopping
# from matplotlib import pyplot as plt
# from config import args

# %%
def xysplit(data):
    xdata = data[data.columns.difference(['L3008_cholesterol', 'L3061_tg', 'L3062_hdl', 'L3068_ldl'])]
    ydata = data[['L3008_cholesterol', 'L3061_tg', 'L3062_hdl', 'L3068_ldl']]
    
    return xdata, ydata

# %%
data1, data2, data3, data4 = DATA_PREPROCESS_SH_v2()
# Out:
# /home/kicarus/anaconda3/envs/kicpy/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (5,6,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/kicarus/anaconda3/envs/kicpy/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data = data1.dropna(axis=0)
xdata, ydata = xysplit(data)
xdata = np.array(xdata)
ydata = np.array(ydata)

data.shape
# Out:
# (15274, 26)

# %%
ydata
# Out:
# array([[204.        ,   5.20948615,  95.        ,  78.        ],
#        [241.        ,   3.95124372,  98.        , 142.        ],
#        [174.        ,   4.4543473 ,  52.        , 105.        ],
#        ...,
#        [239.        ,   4.94164242,  47.        , 158.        ],
#        [204.        ,   5.02388052,  49.        , 124.        ],
#        [293.        ,   4.80402104,  56.        , 181.        ]])

# %%
if torch.cuda.is_available():
    print("Let's go CUDA!!!!!")
    cuda = torch.device('cuda')
else:
    print("No CUDA,,,")
    cuda = torch.device('cpu')

path = 'checkpoint_wolipid.pt'
# y_value = args.y


size = data.shape
data = np.concatenate((NORMALIZATION(xdata, 'standard'), ydata), axis=1)
# data.to_csv('kky1.csv', index=None)

# 0~6 features, 7~10 labels
data = np.array(data)
data = data.astype(float)

# Train / Test split
np.random.shuffle(data)
thres = int(0.9 * len(data))
train = data[:thres]
test = data[thres:]


def _TData(train, y):
    """
     0~14 features, 15~18 labels
    """
    til = size[1] - 4
    train_dataset = TensorDataset(torch.Tensor(train[:, :til]).to(cuda),
                                  torch.Tensor(train[:, y]).to(cuda))

    return train_dataset


def Parameters(net):
    # criterion = nn.CrossEntropyLoss()
    criterion = nn.MSELoss(reduction='mean')
    # optimizer = optim.SGD(net.parameters(), lr=0.000001)
    optimizer = optim.Adam(net.parameters(), lr=0.01)

    return criterion, optimizer

##

def Learning(train_loader, val_loader, nodes, num, patience=10):
    """
        train_loader: 학습시킬 데이터셋 (DataLoader 형식)
        val_loader: 평가할 데이터셋 (DataLoader 형식)
        num: Epochs

    """
    net = DNN_v1(xdata.shape[1], 1, nodes)
    criterion, optimizer = Parameters(net)
    net.to(cuda)

    """Early Stopping Template"""
    for epoch in range(num):
        torch.cuda.empty_cache()
        if epoch == 0:
            early_stopping = EarlyStopping(patience=patience, path=path, verbose=False)
        else:
            early_stopping = EarlyStopping(patience=patience, best_score=best_score, counter=counter, path=path, verbose=False)

        # Training
        net.train()
        running_loss = 0.
        lcnt = 0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)

            outputs = net(inputs)
            loss = criterion(outputs, torch.unsqueeze(labels, 1))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            lcnt += len(labels)

        # Validation
        net.eval()
        net.to(cuda)

        val_loss = 0
        vcnt = 0
        for i, data in enumerate(val_loader):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)
            outputs = net(inputs)

            loss = criterion(outputs, torch.unsqueeze(labels, 1))
            val_loss += loss.item()
            vcnt += len(labels)

        # Template
        best_score, counter, finish = early_stopping(val_loss / vcnt, net)
        # if epoch % 50 == 0:
        #     print('Epoch Now: %d' % epoch)

        if finish:
            break


    net1 = DNN_v1(xdata.shape[1], 1, nodes)
    net1.load_state_dict(torch.load(path))
    net1.eval()

    # output save
    r_label = []
    r_output = []
    val_loss = 0
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)

            outputs = net1(inputs)
            loss = criterion(outputs, torch.unsqueeze(labels, 1))
            val_loss += loss.item()
            outputs = torch.flatten(outputs)

            r_label.append(labels)
            r_output.append(outputs)

        print('Best Epoch: %5d / Last Validation Loss: %5f' % (epoch - patience, val_loss / vcnt))

    return r_label, r_output


def RUN(batch_size, kfold, max_epoch, y_value, node_list, patience):
    print('\n\n\n가즈아~!~!~!~!~!')
    print('y_value: %2d' % y_value)

    rsq_box = []
    for nodes in node_list:
        kf = KFold(n_splits=kfold)
        r_final_label = []
        r_final_output = []
        print('Nodes: %2d' % nodes)
        for train_index, test_index in kf.split(train):
            training, validation = train[train_index], train[test_index]

            train_loader = DataLoader(_TData(training, y_value), batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(_TData(validation, y_value), batch_size=batch_size, shuffle=False)
            r_label, r_output = Learning(train_loader, val_loader, nodes, max_epoch, patience)

            r_final_label += r_label
            r_final_output += r_output

        r_final_label = np.hstack([data.cpu().numpy() for data in r_final_label])
        r_final_output = np.hstack([data.cpu().numpy() for data in r_final_output])
        print('Validation R-squared: %f' % (r2_score(r_final_label, r_final_output)))
        rsq_box.append(r2_score(r_final_label, r_final_output))

    best_node = node_list[rsq_box.index(max(rsq_box))]
    train_loader = DataLoader(_TData(train, y_value), batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(_TData(test, y_value), batch_size=batch_size, shuffle=False)

    labels, outputs = Learning(train_loader, test_loader, best_node, max_epoch, patience)
    labels = np.hstack([data.cpu().numpy() for data in labels])
    outputs = np.hstack([data.cpu().numpy() for data in outputs])

    print('# of node: %d \nTest R-squared: %f' %
          (best_node, r2_score(labels, outputs)))

    return r2_score(labels, outputs)


batch_size = 512
kfold = 5
max_epoch = 1000

n_list = [6, 9, 12, 15, 18, 21, 24, 27, 30]


RUN(batch_size, kfold, max_epoch, y_value=-4, node_list=n_list, patience=50)
RUN(batch_size, kfold, max_epoch, y_value=-3, node_list=n_list, patience=50)
RUN(batch_size, kfold, max_epoch, y_value=-2, node_list=n_list, patience=50)
RUN(batch_size, kfold, max_epoch, y_value=-1, node_list=n_list, patience=50)

# bestnode = int(racc[racc.index(max(racc))])
# Out:
# No CUDA,,,
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -4
# Nodes:  6
# Early Stopping Validated
# Best Epoch:   185 / Last Validation Loss: 2.539266
# Early Stopping Validated
# Best Epoch:   257 / Last Validation Loss: 2.610316
# Early Stopping Validated
# Best Epoch:   170 / Last Validation Loss: 2.726490
# Early Stopping Validated
# Best Epoch:   265 / Last Validation Loss: 2.586019
# Early Stopping Validated
# Best Epoch:   117 / Last Validation Loss: 2.757361
# Validation R-squared: 0.098648
# Nodes:  9
# Early Stopping Validated
# Best Epoch:   100 / Last Validation Loss: 2.537058
# Early Stopping Validated
# Best Epoch:    90 / Last Validation Loss: 2.612528
# Early Stopping Validated
# Best Epoch:    32 / Last Validation Loss: 2.815661
# Early Stopping Validated
# Best Epoch:   144 / Last Validation Loss: 2.574887
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 2.656793
# Validation R-squared: 0.098935
# Nodes: 12
# Early Stopping Validated
# Best Epoch:   114 / Last Validation Loss: 2.526343
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 2.606193
# Early Stopping Validated
# Best Epoch:    33 / Last Validation Loss: 2.719600
# Early Stopping Validated
# Best Epoch:    71 / Last Validation Loss: 2.552437
# Early Stopping Validated
# Best Epoch:    34 / Last Validation Loss: 2.698798
# Validation R-squared: 0.105856
# Nodes: 15
# Early Stopping Validated
# Best Epoch:    29 / Last Validation Loss: 2.544628
# Early Stopping Validated
# Best Epoch:   100 / Last Validation Loss: 2.640109
# Early Stopping Validated
# Best Epoch:    28 / Last Validation Loss: 2.736138
# Early Stopping Validated
# Best Epoch:   124 / Last Validation Loss: 2.548362
# Early Stopping Validated
# Best Epoch:    44 / Last Validation Loss: 2.670520
# Validation R-squared: 0.103291
# Nodes: 18
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 2.533498
# Early Stopping Validated
# Best Epoch:    43 / Last Validation Loss: 2.595285
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 2.770735
# Early Stopping Validated
# Best Epoch:    39 / Last Validation Loss: 2.569643
# Early Stopping Validated
# Best Epoch:    38 / Last Validation Loss: 2.666771
# Validation R-squared: 0.102056
# Nodes: 21
# Early Stopping Validated
# Best Epoch:   259 / Last Validation Loss: 2.524452
# Early Stopping Validated
# Best Epoch:    37 / Last Validation Loss: 2.615169
# Early Stopping Validated
# Best Epoch:    72 / Last Validation Loss: 2.729305
# Early Stopping Validated
# Best Epoch:    86 / Last Validation Loss: 2.555258
# Early Stopping Validated
# Best Epoch:    62 / Last Validation Loss: 2.663121
# Validation R-squared: 0.106613
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    29 / Last Validation Loss: 2.518687
# Early Stopping Validated
# Best Epoch:    66 / Last Validation Loss: 2.612585
# Early Stopping Validated
# Best Epoch:   112 / Last Validation Loss: 2.779105
# Early Stopping Validated
# Best Epoch:    49 / Last Validation Loss: 2.557083
# Early Stopping Validated
# Best Epoch:    42 / Last Validation Loss: 2.658927
# Validation R-squared: 0.102740
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    45 / Last Validation Loss: 2.550551
# Early Stopping Validated
# Best Epoch:    43 / Last Validation Loss: 2.615814
# Early Stopping Validated
# Best Epoch:    94 / Last Validation Loss: 2.770161
# Early Stopping Validated
# Best Epoch:    66 / Last Validation Loss: 2.562735
# Early Stopping Validated
# Best Epoch:    26 / Last Validation Loss: 2.648310
# Validation R-squared: 0.101592
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    67 / Last Validation Loss: 2.534435
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 2.611043
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 2.777899
# Early Stopping Validated
# Best Epoch:    68 / Last Validation Loss: 2.561486
# Early Stopping Validated
# Best Epoch:    28 / Last Validation Loss: 2.661587
# Validation R-squared: 0.102634
# Early Stopping Validated
# Best Epoch:    42 / Last Validation Loss: 2.262626
# # of node: 21
# Test R-squared: 0.125193
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -3
# Nodes:  6
# Early Stopping Validated
# Best Epoch:   226 / Last Validation Loss: 0.000328
# Early Stopping Validated
# Best Epoch:   241 / Last Validation Loss: 0.000361
# Early Stopping Validated
# Best Epoch:    53 / Last Validation Loss: 0.000362
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 0.000356
# Early Stopping Validated
# Best Epoch:   119 / Last Validation Loss: 0.000356
# Validation R-squared: 0.183659
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    80 / Last Validation Loss: 0.000330
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 0.000365
# Early Stopping Validated
# Best Epoch:   248 / Last Validation Loss: 0.000353
# Early Stopping Validated
# Best Epoch:   222 / Last Validation Loss: 0.000350
# Early Stopping Validated
# Best Epoch:   105 / Last Validation Loss: 0.000360
# Validation R-squared: 0.186666
# Nodes: 12
# Early Stopping Validated
# Best Epoch:   176 / Last Validation Loss: 0.000334
# Early Stopping Validated
# Best Epoch:   208 / Last Validation Loss: 0.000362
# Early Stopping Validated
# Best Epoch:    87 / Last Validation Loss: 0.000372
# Early Stopping Validated
# Best Epoch:   193 / Last Validation Loss: 0.000352
# Early Stopping Validated
# Best Epoch:   131 / Last Validation Loss: 0.000351
# Validation R-squared: 0.179282
# Nodes: 15
# Early Stopping Validated
# Best Epoch:    54 / Last Validation Loss: 0.000336
# Early Stopping Validated
# Best Epoch:   219 / Last Validation Loss: 0.000363
# Early Stopping Validated
# Best Epoch:   103 / Last Validation Loss: 0.000377
# Early Stopping Validated
# Best Epoch:   219 / Last Validation Loss: 0.000352
# Early Stopping Validated
# Best Epoch:   176 / Last Validation Loss: 0.000362
# Validation R-squared: 0.170621
# Nodes: 18
# Early Stopping Validated
# Best Epoch:   175 / Last Validation Loss: 0.000330
# Early Stopping Validated
# Best Epoch:    99 / Last Validation Loss: 0.000368
# Early Stopping Validated
# Best Epoch:   137 / Last Validation Loss: 0.000406
# Early Stopping Validated
# Best Epoch:   234 / Last Validation Loss: 0.000350
# Early Stopping Validated
# Best Epoch:    38 / Last Validation Loss: 0.000365
# Validation R-squared: 0.155252
# Nodes: 21
# Early Stopping Validated
# Best Epoch:   246 / Last Validation Loss: 0.000328
# Early Stopping Validated
# Best Epoch:    26 / Last Validation Loss: 0.000370
# Early Stopping Validated
# Best Epoch:   187 / Last Validation Loss: 0.000431
# Early Stopping Validated
# Best Epoch:   200 / Last Validation Loss: 0.000342
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 0.000372
# Validation R-squared: 0.142459
# Nodes: 24
# Early Stopping Validated
# Best Epoch:   176 / Last Validation Loss: 0.000323
# Early Stopping Validated
# Best Epoch:   133 / Last Validation Loss: 0.000363
# Early Stopping Validated
# Best Epoch:   182 / Last Validation Loss: 0.000412
# Early Stopping Validated
# Best Epoch:    98 / Last Validation Loss: 0.000339
# Early Stopping Validated
# Best Epoch:   158 / Last Validation Loss: 0.000365
# Validation R-squared: 0.163287
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    79 / Last Validation Loss: 0.000329
# Early Stopping Validated
# Best Epoch:    83 / Last Validation Loss: 0.000352
# Early Stopping Validated
# Best Epoch:   237 / Last Validation Loss: 0.000400
# Early Stopping Validated
# Best Epoch:   117 / Last Validation Loss: 0.000342
# Early Stopping Validated
# Best Epoch:   123 / Last Validation Loss: 0.000368
# Validation R-squared: 0.166703
# Nodes: 30
# Early Stopping Validated
# Best Epoch:   119 / Last Validation Loss: 0.000327
# Early Stopping Validated
# Best Epoch:   290 / Last Validation Loss: 0.000346
# Early Stopping Validated
# Best Epoch:   218 / Last Validation Loss: 0.000371
# Early Stopping Validated
# Best Epoch:    77 / Last Validation Loss: 0.000346
# Early Stopping Validated
# Best Epoch:    68 / Last Validation Loss: 0.000350
# Validation R-squared: 0.193770
# Early Stopping Validated
# Best Epoch:    71 / Last Validation Loss: 0.000294
# # of node: 30
# Test R-squared: 0.211534
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -2
# Nodes:  6
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 0.475703
# Early Stopping Validated
# Best Epoch:    88 / Last Validation Loss: 0.484401
# Early Stopping Validated
# Best Epoch:    21 / Last Validation Loss: 0.477342
# Early Stopping Validated
# Best Epoch:    83 / Last Validation Loss: 0.465908
# Early Stopping Validated
# Best Epoch:    49 / Last Validation Loss: 0.457431
# Validation R-squared: 0.210251
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 0.475469
# Early Stopping Validated
# Best Epoch:   115 / Last Validation Loss: 0.485544
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 0.477842
# Early Stopping Validated
# Best Epoch:    29 / Last Validation Loss: 0.465892
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 0.458060
# Validation R-squared: 0.208899
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    91 / Last Validation Loss: 0.473280
# Early Stopping Validated
# Best Epoch:    43 / Last Validation Loss: 0.487073
# Early Stopping Validated
# Best Epoch:    18 / Last Validation Loss: 0.485215
# Early Stopping Validated
# Best Epoch:    51 / Last Validation Loss: 0.467994
# Early Stopping Validated
# Best Epoch:    34 / Last Validation Loss: 0.456306
# Validation R-squared: 0.206829
# Nodes: 15
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 0.473959
# Early Stopping Validated
# Best Epoch:    25 / Last Validation Loss: 0.485417
# Early Stopping Validated
# Best Epoch:    22 / Last Validation Loss: 0.480141
# Early Stopping Validated
# Best Epoch:    53 / Last Validation Loss: 0.468031
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 0.457675
# Validation R-squared: 0.208171
# Nodes: 18
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 0.474293
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.485098
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.479613
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 0.466747
# Early Stopping Validated
# Best Epoch:    23 / Last Validation Loss: 0.454820
# Validation R-squared: 0.208603
# Nodes: 21
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.475294
# Early Stopping Validated
# Best Epoch:    15 / Last Validation Loss: 0.486633
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 0.478408
# Early Stopping Validated
# Best Epoch:    43 / Last Validation Loss: 0.465592
# Early Stopping Validated
# Best Epoch:    28 / Last Validation Loss: 0.454217
# Validation R-squared: 0.209623
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    15 / Last Validation Loss: 0.474989
# Early Stopping Validated
# Best Epoch:     9 / Last Validation Loss: 0.487330
# Early Stopping Validated
# Best Epoch:    58 / Last Validation Loss: 0.483758
# Early Stopping Validated
# Best Epoch:    22 / Last Validation Loss: 0.467253
# Early Stopping Validated
# Best Epoch:    25 / Last Validation Loss: 0.456586
# Validation R-squared: 0.206313
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    60 / Last Validation Loss: 0.474340
# Early Stopping Validated
# Best Epoch:    37 / Last Validation Loss: 0.484229
# Early Stopping Validated
# Best Epoch:     7 / Last Validation Loss: 0.479367
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 0.465611
# Early Stopping Validated
# Best Epoch:    52 / Last Validation Loss: 0.455332
# Validation R-squared: 0.209488
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 0.473821
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 0.484250
# Early Stopping Validated
# Best Epoch:    11 / Last Validation Loss: 0.481480
# Early Stopping Validated
# Best Epoch:    28 / Last Validation Loss: 0.465620
# Early Stopping Validated
# Best Epoch:    18 / Last Validation Loss: 0.456578
# Validation R-squared: 0.208079
# Early Stopping Validated
# Best Epoch:    69 / Last Validation Loss: 0.428982
# # of node: 6
# Test R-squared: 0.226757
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -1
# Nodes:  6
# Early Stopping Validated
# Best Epoch:   216 / Last Validation Loss: 2.070181
# Early Stopping Validated
# Best Epoch:   147 / Last Validation Loss: 2.212647
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 2.243313
# Early Stopping Validated
# Best Epoch:   101 / Last Validation Loss: 2.069537
# Early Stopping Validated
# Best Epoch:    44 / Last Validation Loss: 2.344931
# Validation R-squared: 0.125692
# Nodes:  9
# Early Stopping Validated
# Best Epoch:   170 / Last Validation Loss: 2.066999
# Early Stopping Validated
# Best Epoch:   184 / Last Validation Loss: 2.315434
# Early Stopping Validated
# Best Epoch:    39 / Last Validation Loss: 2.246892
# Early Stopping Validated
# Best Epoch:    84 / Last Validation Loss: 2.081959
# Early Stopping Validated
# Best Epoch:    62 / Last Validation Loss: 2.348693
# Validation R-squared: 0.116555
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    96 / Last Validation Loss: 2.064281
# Early Stopping Validated
# Best Epoch:    29 / Last Validation Loss: 2.325990
# Early Stopping Validated
# Best Epoch:    21 / Last Validation Loss: 2.254387
# Early Stopping Validated
# Best Epoch:    58 / Last Validation Loss: 2.091545
# Early Stopping Validated
# Best Epoch:    72 / Last Validation Loss: 2.340899
# Validation R-squared: 0.115649
# Nodes: 15
# Early Stopping Validated
# Best Epoch:   180 / Last Validation Loss: 2.061251
# Early Stopping Validated
# Best Epoch:   443 / Last Validation Loss: 2.294463
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 2.265642
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 2.085508
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 2.353789
# Validation R-squared: 0.116329
# Nodes: 18
# Early Stopping Validated
# Best Epoch:   167 / Last Validation Loss: 2.076740
# Early Stopping Validated
# Best Epoch:   101 / Last Validation Loss: 2.306781
# Early Stopping Validated
# Best Epoch:    21 / Last Validation Loss: 2.274921
# Early Stopping Validated
# Best Epoch:    60 / Last Validation Loss: 2.080475
# Early Stopping Validated
# Best Epoch:    60 / Last Validation Loss: 2.335870
# Validation R-squared: 0.115709
# Nodes: 21
# Early Stopping Validated
# Best Epoch:    65 / Last Validation Loss: 2.076493
# Early Stopping Validated
# Best Epoch:   164 / Last Validation Loss: 2.295862
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 2.260168
# Early Stopping Validated
# Best Epoch:    26 / Last Validation Loss: 2.078561
# Early Stopping Validated
# Best Epoch:    51 / Last Validation Loss: 2.341695
# Validation R-squared: 0.116886
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    75 / Last Validation Loss: 2.078136
# Early Stopping Validated
# Best Epoch:   264 / Last Validation Loss: 2.297287
# Early Stopping Validated
# Best Epoch:    13 / Last Validation Loss: 2.280856
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 2.078748
# Early Stopping Validated
# Best Epoch:    14 / Last Validation Loss: 2.352659
# Validation R-squared: 0.114039
# Nodes: 27
# Early Stopping Validated
# Best Epoch:   121 / Last Validation Loss: 2.074744
# Early Stopping Validated
# Best Epoch:    98 / Last Validation Loss: 2.316458
# Early Stopping Validated
# Best Epoch:    12 / Last Validation Loss: 2.269397
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 2.084112
# Early Stopping Validated
# Best Epoch:    62 / Last Validation Loss: 2.352171
# Validation R-squared: 0.114469
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    50 / Last Validation Loss: 2.063925
# Early Stopping Validated
# Best Epoch:    55 / Last Validation Loss: 2.317516
# Early Stopping Validated
# Best Epoch:    19 / Last Validation Loss: 2.281557
# Early Stopping Validated
# Best Epoch:    51 / Last Validation Loss: 2.082209
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 2.356732
# Validation R-squared: 0.113634
# Early Stopping Validated
# Best Epoch:    91 / Last Validation Loss: 1.896611
# # of node: 6
# Test R-squared: 0.144154
# 0.14415412056247567
