# %% [markdown]
# #
# # 이전 Lipid Profile 추가하고 R스퀘어 계산

# %%
##
import numpy as np
import pandas as pd
from import_data import *
import torch
import torch.optim as optim
import torch.nn as nn
from network import DNN, DNN_v1
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score
from utils import EarlyStopping
# from matplotlib import pyplot as plt
# from config import args

# %%
data1, data2, data3, data4 = DATA_PREPROCESS_SH_v2()
# Out:
# /home/kicarus/anaconda3/envs/kicpy/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (5,6,14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# /home/kicarus/anaconda3/envs/kicpy/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data = data2.dropna(axis=0)
xdata, ydata = xysplit(data)
xdata = np.array(xdata)
ydata = np.array(ydata)

data.shape
# Out:
# (5382, 31)

# %%
path = 'checkpoint_wlipid.pt'

# %%
if torch.cuda.is_available():
    print("Let's go CUDA!!!!!")
    cuda = torch.device('cuda')
else:
    print("No CUDA,,,")
    cuda = torch.device('cpu')


# y_value = args.y


size = data.shape
data = np.concatenate((NORMALIZATION(xdata, 'standard'), ydata), axis=1)
# data.to_csv('kky1.csv', index=None)

# 0~6 features, 7~10 labels
data = np.array(data)
data = data.astype(float)

# Train / Test split
np.random.shuffle(data)
thres = int(0.9 * len(data))
train = data[:thres]
test = data[thres:]


def _TData(train, y):
    """
     0~14 features, 15~18 labels
    """
    til = size[1] - 4
    train_dataset = TensorDataset(torch.Tensor(train[:, :til]).to(cuda),
                                  torch.Tensor(train[:, y]).to(cuda))

    return train_dataset


def Parameters(net):
    # criterion = nn.CrossEntropyLoss()
    criterion = nn.MSELoss(reduction='mean')
    # optimizer = optim.SGD(net.parameters(), lr=0.000001)
    optimizer = optim.Adam(net.parameters(), lr=0.01)

    return criterion, optimizer

##

def Learning(train_loader, val_loader, nodes, num, patience=10):
    """
        train_loader: 학습시킬 데이터셋 (DataLoader 형식)
        val_loader: 평가할 데이터셋 (DataLoader 형식)
        num: Epochs

    """
    net = DNN_v1(xdata.shape[1], 1, nodes)
    criterion, optimizer = Parameters(net)
    net.to(cuda)

    """Early Stopping Template"""
    for epoch in range(num):
        torch.cuda.empty_cache()
        if epoch == 0:
            early_stopping = EarlyStopping(patience=patience, path=path, verbose=False)
        else:
            early_stopping = EarlyStopping(patience=patience, best_score=best_score, counter=counter, path=path, verbose=False)

        # Training
        net.train()
        running_loss = 0.
        lcnt = 0
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)

            outputs = net(inputs)
            loss = criterion(outputs, torch.unsqueeze(labels, 1))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            lcnt += len(labels)

        # Validation
        net.eval()
        net.to(cuda)

        val_loss = 0
        vcnt = 0
        for i, data in enumerate(val_loader):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)
            outputs = net(inputs)

            loss = criterion(outputs, torch.unsqueeze(labels, 1))
            val_loss += loss.item()
            vcnt += len(labels)

        # Template
        best_score, counter, finish = early_stopping(val_loss / vcnt, net)
        # if epoch % 50 == 0:
        #     print('Epoch Now: %d' % epoch)

        if finish:
            break


    net1 = DNN_v1(xdata.shape[1], 1, nodes)
    net1.load_state_dict(torch.load(path))
    net1.eval()

    # output save
    r_label = []
    r_output = []
    val_loss = 0
    with torch.no_grad():
        for i, data in enumerate(val_loader):
            inputs, labels = data
            inputs = inputs.to(cuda)
            labels = labels.to(cuda)

            outputs = net1(inputs)
            loss = criterion(outputs, torch.unsqueeze(labels, 1))
            val_loss += loss.item()
            outputs = torch.flatten(outputs)

            r_label.append(labels)
            r_output.append(outputs)

        print('Best Epoch: %5d / Last Validation Loss: %5f' % (epoch - patience, val_loss / vcnt))

    return r_label, r_output


def RUN(batch_size, kfold, max_epoch, y_value, node_list, patience):
    print('\n\n\n가즈아~!~!~!~!~!')
    print('y_value: %2d' % y_value)

    rsq_box = []
    for nodes in node_list:
        kf = KFold(n_splits=kfold)
        r_final_label = []
        r_final_output = []
        print('Nodes: %2d' % nodes)
        for train_index, test_index in kf.split(train):
            training, validation = train[train_index], train[test_index]

            train_loader = DataLoader(_TData(training, y_value), batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(_TData(validation, y_value), batch_size=batch_size, shuffle=False)
            r_label, r_output = Learning(train_loader, val_loader, nodes, max_epoch, patience)

            r_final_label += r_label
            r_final_output += r_output

        r_final_label = np.hstack([data.cpu().numpy() for data in r_final_label])
        r_final_output = np.hstack([data.cpu().numpy() for data in r_final_output])
        print('Validation R-squared: %f' % (r2_score(r_final_label, r_final_output)))
        rsq_box.append(r2_score(r_final_label, r_final_output))

    best_node = node_list[rsq_box.index(max(rsq_box))]
    train_loader = DataLoader(_TData(train, y_value), batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(_TData(test, y_value), batch_size=batch_size, shuffle=False)

    labels, outputs = Learning(train_loader, test_loader, best_node, max_epoch, patience)
    labels = np.hstack([data.cpu().numpy() for data in labels])
    outputs = np.hstack([data.cpu().numpy() for data in outputs])

    print('# of node: %d \nTest R-squared: %f' %
          (best_node, r2_score(labels, outputs)))

    return r2_score(labels, outputs)


batch_size = 512
kfold = 5
max_epoch = 1000

n_list = [6, 9, 12, 15, 18, 21, 24, 27, 30]


RUN(batch_size, kfold, max_epoch, y_value=-4, node_list=n_list, patience=50)
RUN(batch_size, kfold, max_epoch, y_value=-3, node_list=n_list, patience=50)
RUN(batch_size, kfold, max_epoch, y_value=-2, node_list=n_list, patience=50)
RUN(batch_size, kfold, max_epoch, y_value=-1, node_list=n_list, patience=50)

# bestnode = int(racc[racc.index(max(racc))])
# Out:
# No CUDA,,,
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -4
# Nodes:  6
# Early Stopping Validated
# Best Epoch:   120 / Last Validation Loss: 1.555949
# Early Stopping Validated
# Best Epoch:    95 / Last Validation Loss: 1.475831
# Early Stopping Validated
# Best Epoch:   196 / Last Validation Loss: 1.751194
# Early Stopping Validated
# Best Epoch:    93 / Last Validation Loss: 1.467421
# Early Stopping Validated
# Best Epoch:    72 / Last Validation Loss: 1.401105
# Validation R-squared: 0.448230
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    67 / Last Validation Loss: 1.566378
# Early Stopping Validated
# Best Epoch:    69 / Last Validation Loss: 1.494482
# Early Stopping Validated
# Best Epoch:   283 / Last Validation Loss: 1.725021
# Early Stopping Validated
# Best Epoch:   225 / Last Validation Loss: 1.441782
# Early Stopping Validated
# Best Epoch:   158 / Last Validation Loss: 1.429079
# Validation R-squared: 0.447826
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    99 / Last Validation Loss: 1.565663
# Early Stopping Validated
# Best Epoch:   118 / Last Validation Loss: 1.516158
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 1.738209
# Early Stopping Validated
# Best Epoch:    72 / Last Validation Loss: 1.463586
# Early Stopping Validated
# Best Epoch:    62 / Last Validation Loss: 1.433310
# Validation R-squared: 0.443405
# Nodes: 15
# Early Stopping Validated
# Best Epoch:    57 / Last Validation Loss: 1.579066
# Early Stopping Validated
# Best Epoch:    58 / Last Validation Loss: 1.481562
# Early Stopping Validated
# Best Epoch:    50 / Last Validation Loss: 1.705023
# Early Stopping Validated
# Best Epoch:    69 / Last Validation Loss: 1.456562
# Early Stopping Validated
# Best Epoch:   114 / Last Validation Loss: 1.431623
# Validation R-squared: 0.447953
# Nodes: 18
# Early Stopping Validated
# Best Epoch:   114 / Last Validation Loss: 1.572382
# Early Stopping Validated
# Best Epoch:    82 / Last Validation Loss: 1.491638
# Early Stopping Validated
# Best Epoch:    53 / Last Validation Loss: 1.698260
# Early Stopping Validated
# Best Epoch:    81 / Last Validation Loss: 1.461035
# Early Stopping Validated
# Best Epoch:    92 / Last Validation Loss: 1.402200
# Validation R-squared: 0.450039
# Nodes: 21
# Early Stopping Validated
# Best Epoch:   179 / Last Validation Loss: 1.568088
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 1.477595
# Early Stopping Validated
# Best Epoch:    60 / Last Validation Loss: 1.704340
# Early Stopping Validated
# Best Epoch:    90 / Last Validation Loss: 1.450083
# Early Stopping Validated
# Best Epoch:   112 / Last Validation Loss: 1.397745
# Validation R-squared: 0.452256
# Nodes: 24
# Early Stopping Validated
# Best Epoch:   147 / Last Validation Loss: 1.557994
# Early Stopping Validated
# Best Epoch:    77 / Last Validation Loss: 1.487847
# Early Stopping Validated
# Best Epoch:    43 / Last Validation Loss: 1.706480
# Early Stopping Validated
# Best Epoch:   145 / Last Validation Loss: 1.432714
# Early Stopping Validated
# Best Epoch:   108 / Last Validation Loss: 1.397735
# Validation R-squared: 0.453048
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    89 / Last Validation Loss: 1.557979
# Early Stopping Validated
# Best Epoch:    89 / Last Validation Loss: 1.478960
# Early Stopping Validated
# Best Epoch:    42 / Last Validation Loss: 1.723692
# Early Stopping Validated
# Best Epoch:    58 / Last Validation Loss: 1.454780
# Early Stopping Validated
# Best Epoch:    63 / Last Validation Loss: 1.430678
# Validation R-squared: 0.448590
# Nodes: 30
# Early Stopping Validated
# Best Epoch:   109 / Last Validation Loss: 1.569341
# Early Stopping Validated
# Best Epoch:   161 / Last Validation Loss: 1.499089
# Early Stopping Validated
# Best Epoch:    44 / Last Validation Loss: 1.679968
# Early Stopping Validated
# Best Epoch:    35 / Last Validation Loss: 1.445021
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 1.411542
# Validation R-squared: 0.451473
# Early Stopping Validated
# Best Epoch:    61 / Last Validation Loss: 2.098798
# # of node: 24
# Test R-squared: 0.411832
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -3
# Nodes:  6
# Early Stopping Validated
# Best Epoch:    62 / Last Validation Loss: 0.000295
# Early Stopping Validated
# Best Epoch:    67 / Last Validation Loss: 0.000299
# Early Stopping Validated
# Best Epoch:    43 / Last Validation Loss: 0.000288
# Early Stopping Validated
# Best Epoch:    30 / Last Validation Loss: 0.000276
# Early Stopping Validated
# Best Epoch:    68 / Last Validation Loss: 0.000276
# Validation R-squared: 0.292493
# Nodes:  9
# Early Stopping Validated
# Best Epoch:   105 / Last Validation Loss: 0.000299
# Early Stopping Validated
# Best Epoch:    35 / Last Validation Loss: 0.000314
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 0.000294
# Early Stopping Validated
# Best Epoch:    41 / Last Validation Loss: 0.000282
# Early Stopping Validated
# Best Epoch:    38 / Last Validation Loss: 0.000284
# Validation R-squared: 0.273302
# Nodes: 12
# Early Stopping Validated
# Best Epoch:   142 / Last Validation Loss: 0.000301
# Early Stopping Validated
# Best Epoch:    93 / Last Validation Loss: 0.000291
# Early Stopping Validated
# Best Epoch:    49 / Last Validation Loss: 0.000295
# Early Stopping Validated
# Best Epoch:    71 / Last Validation Loss: 0.000290
# Early Stopping Validated
# Best Epoch:   106 / Last Validation Loss: 0.000283
# Validation R-squared: 0.279405
# Nodes: 15
# Early Stopping Validated
# Best Epoch:   130 / Last Validation Loss: 0.000312
# Early Stopping Validated
# Best Epoch:    83 / Last Validation Loss: 0.000312
# Early Stopping Validated
# Best Epoch:   108 / Last Validation Loss: 0.000302
# Early Stopping Validated
# Best Epoch:    68 / Last Validation Loss: 0.000283
# Early Stopping Validated
# Best Epoch:    77 / Last Validation Loss: 0.000290
# Validation R-squared: 0.259654
# Nodes: 18
# Early Stopping Validated
# Best Epoch:   181 / Last Validation Loss: 0.000322
# Early Stopping Validated
# Best Epoch:   124 / Last Validation Loss: 0.000305
# Early Stopping Validated
# Best Epoch:   111 / Last Validation Loss: 0.000305
# Early Stopping Validated
# Best Epoch:   131 / Last Validation Loss: 0.000289
# Early Stopping Validated
# Best Epoch:   111 / Last Validation Loss: 0.000292
# Validation R-squared: 0.253847
# Nodes: 21
# Early Stopping Validated
# Best Epoch:    54 / Last Validation Loss: 0.000312
# Early Stopping Validated
# Best Epoch:   112 / Last Validation Loss: 0.000308
# Early Stopping Validated
# Best Epoch:   186 / Last Validation Loss: 0.000304
# Early Stopping Validated
# Best Epoch:    65 / Last Validation Loss: 0.000306
# Early Stopping Validated
# Best Epoch:   134 / Last Validation Loss: 0.000288
# Validation R-squared: 0.251010
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    61 / Last Validation Loss: 0.000326
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 0.000311
# Early Stopping Validated
# Best Epoch:   119 / Last Validation Loss: 0.000305
# Early Stopping Validated
# Best Epoch:    87 / Last Validation Loss: 0.000296
# Early Stopping Validated
# Best Epoch:   130 / Last Validation Loss: 0.000298
# Validation R-squared: 0.242855
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    41 / Last Validation Loss: 0.000336
# Early Stopping Validated
# Best Epoch:   139 / Last Validation Loss: 0.000303
# Early Stopping Validated
# Best Epoch:   120 / Last Validation Loss: 0.000302
# Early Stopping Validated
# Best Epoch:   245 / Last Validation Loss: 0.000303
# Early Stopping Validated
# Best Epoch:   182 / Last Validation Loss: 0.000294
# Validation R-squared: 0.240924
# Nodes: 30
# Early Stopping Validated
# Best Epoch:   111 / Last Validation Loss: 0.000318
# Early Stopping Validated
# Best Epoch:    97 / Last Validation Loss: 0.000310
# Early Stopping Validated
# Best Epoch:   142 / Last Validation Loss: 0.000303
# Early Stopping Validated
# Best Epoch:   250 / Last Validation Loss: 0.000290
# Early Stopping Validated
# Best Epoch:   156 / Last Validation Loss: 0.000298
# Validation R-squared: 0.250488
# Early Stopping Validated
# Best Epoch:   128 / Last Validation Loss: 0.000444
# # of node: 6
# Test R-squared: 0.352270
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -2
# Nodes:  6
# Early Stopping Validated
# Best Epoch:   157 / Last Validation Loss: 0.199340
# Early Stopping Validated
# Best Epoch:   276 / Last Validation Loss: 0.209834
# Early Stopping Validated
# Best Epoch:    93 / Last Validation Loss: 0.223375
# Early Stopping Validated
# Best Epoch:    85 / Last Validation Loss: 0.185745
# Early Stopping Validated
# Best Epoch:   158 / Last Validation Loss: 0.193161
# Validation R-squared: 0.640290
# Nodes:  9
# Early Stopping Validated
# Best Epoch:   296 / Last Validation Loss: 0.206307
# Early Stopping Validated
# Best Epoch:   135 / Last Validation Loss: 0.215185
# Early Stopping Validated
# Best Epoch:    46 / Last Validation Loss: 0.229414
# Early Stopping Validated
# Best Epoch:    85 / Last Validation Loss: 0.184262
# Early Stopping Validated
# Best Epoch:    79 / Last Validation Loss: 0.197428
# Validation R-squared: 0.633001
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    96 / Last Validation Loss: 0.198439
# Early Stopping Validated
# Best Epoch:   110 / Last Validation Loss: 0.218843
# Early Stopping Validated
# Best Epoch:    27 / Last Validation Loss: 0.225991
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 0.190086
# Early Stopping Validated
# Best Epoch:    75 / Last Validation Loss: 0.195540
# Validation R-squared: 0.634506
# Nodes: 15
# Early Stopping Validated
# Best Epoch:   107 / Last Validation Loss: 0.203548
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 0.220306
# Early Stopping Validated
# Best Epoch:    41 / Last Validation Loss: 0.222165
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 0.188765
# Early Stopping Validated
# Best Epoch:    64 / Last Validation Loss: 0.193484
# Validation R-squared: 0.634823
# Nodes: 18
# Early Stopping Validated
# Best Epoch:    39 / Last Validation Loss: 0.200171
# Early Stopping Validated
# Best Epoch:    86 / Last Validation Loss: 0.217339
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 0.225899
# Early Stopping Validated
# Best Epoch:    95 / Last Validation Loss: 0.187300
# Early Stopping Validated
# Best Epoch:    45 / Last Validation Loss: 0.188714
# Validation R-squared: 0.637923
# Nodes: 21
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.203236
# Early Stopping Validated
# Best Epoch:    26 / Last Validation Loss: 0.213032
# Early Stopping Validated
# Best Epoch:    54 / Last Validation Loss: 0.225324
# Early Stopping Validated
# Best Epoch:    64 / Last Validation Loss: 0.189623
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 0.191125
# Validation R-squared: 0.636834
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    51 / Last Validation Loss: 0.199656
# Early Stopping Validated
# Best Epoch:    33 / Last Validation Loss: 0.214919
# Early Stopping Validated
# Best Epoch:    22 / Last Validation Loss: 0.219694
# Early Stopping Validated
# Best Epoch:    78 / Last Validation Loss: 0.186349
# Early Stopping Validated
# Best Epoch:    55 / Last Validation Loss: 0.191547
# Validation R-squared: 0.640319
# Nodes: 27
# Early Stopping Validated
# Best Epoch:    29 / Last Validation Loss: 0.197115
# Early Stopping Validated
# Best Epoch:    27 / Last Validation Loss: 0.215232
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.218669
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.187195
# Early Stopping Validated
# Best Epoch:    47 / Last Validation Loss: 0.191405
# Validation R-squared: 0.641364
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    63 / Last Validation Loss: 0.199662
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 0.214415
# Early Stopping Validated
# Best Epoch:    17 / Last Validation Loss: 0.220984
# Early Stopping Validated
# Best Epoch:    49 / Last Validation Loss: 0.189246
# Early Stopping Validated
# Best Epoch:    64 / Last Validation Loss: 0.194539
# Validation R-squared: 0.637981
# Early Stopping Validated
# Best Epoch:    24 / Last Validation Loss: 0.334587
# # of node: 27
# Test R-squared: 0.614337
#
#
#
# 가즈아~!~!~!~!~!
# y_value: -1
# Nodes:  6
# Early Stopping Validated
# Best Epoch:    76 / Last Validation Loss: 1.327154
# Early Stopping Validated
# Best Epoch:   115 / Last Validation Loss: 1.279252
# Early Stopping Validated
# Best Epoch:   155 / Last Validation Loss: 1.373528
# Early Stopping Validated
# Best Epoch:    54 / Last Validation Loss: 1.169318
# Early Stopping Validated
# Best Epoch:    63 / Last Validation Loss: 1.193888
# Validation R-squared: 0.437234
# Nodes:  9
# Early Stopping Validated
# Best Epoch:    81 / Last Validation Loss: 1.331354
# Early Stopping Validated
# Best Epoch:    41 / Last Validation Loss: 1.276426
# Early Stopping Validated
# Best Epoch:    59 / Last Validation Loss: 1.374816
# Early Stopping Validated
# Best Epoch:   101 / Last Validation Loss: 1.145784
# Early Stopping Validated
# Best Epoch:    39 / Last Validation Loss: 1.195878
# Validation R-squared: 0.438988
# Nodes: 12
# Early Stopping Validated
# Best Epoch:    65 / Last Validation Loss: 1.327953
# Early Stopping Validated
# Best Epoch:   110 / Last Validation Loss: 1.271910
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 1.380869
# Early Stopping Validated
# Best Epoch:    53 / Last Validation Loss: 1.155590
# Early Stopping Validated
# Best Epoch:    44 / Last Validation Loss: 1.198487
# Validation R-squared: 0.438137
# Nodes: 15
# Early Stopping Validated
# Best Epoch:    53 / Last Validation Loss: 1.324402
# Early Stopping Validated
# Best Epoch:   124 / Last Validation Loss: 1.262736
# Early Stopping Validated
# Best Epoch:   117 / Last Validation Loss: 1.357090
# Early Stopping Validated
# Best Epoch:    34 / Last Validation Loss: 1.151744
# Early Stopping Validated
# Best Epoch:    40 / Last Validation Loss: 1.201134
# Validation R-squared: 0.441384
# Nodes: 18
# Early Stopping Validated
# Best Epoch:    67 / Last Validation Loss: 1.323573
# Early Stopping Validated
# Best Epoch:    60 / Last Validation Loss: 1.265756
# Early Stopping Validated
# Best Epoch:    54 / Last Validation Loss: 1.368067
# Early Stopping Validated
# Best Epoch:   153 / Last Validation Loss: 1.142657
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 1.182916
# Validation R-squared: 0.442699
# Nodes: 21
# Early Stopping Validated
# Best Epoch:    48 / Last Validation Loss: 1.328376
# Early Stopping Validated
# Best Epoch:    73 / Last Validation Loss: 1.265296
# Early Stopping Validated
# Best Epoch:    66 / Last Validation Loss: 1.368635
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 1.167545
# Early Stopping Validated
# Best Epoch:    61 / Last Validation Loss: 1.197569
# Validation R-squared: 0.438561
# Nodes: 24
# Early Stopping Validated
# Best Epoch:    30 / Last Validation Loss: 1.320806
# Early Stopping Validated
# Best Epoch:    51 / Last Validation Loss: 1.261164
# Early Stopping Validated
# Best Epoch:    41 / Last Validation Loss: 1.362673
# Early Stopping Validated
# Best Epoch:    52 / Last Validation Loss: 1.149074
# Early Stopping Validated
# Best Epoch:    51 / Last Validation Loss: 1.173796
# Validation R-squared: 0.444007
# Nodes: 27
# Early Stopping Validated
# Best Epoch:   110 / Last Validation Loss: 1.315417
# Early Stopping Validated
# Best Epoch:    34 / Last Validation Loss: 1.264014
# Early Stopping Validated
# Best Epoch:    31 / Last Validation Loss: 1.358103
# Early Stopping Validated
# Best Epoch:    63 / Last Validation Loss: 1.154081
# Early Stopping Validated
# Best Epoch:    36 / Last Validation Loss: 1.183026
# Validation R-squared: 0.443320
# Nodes: 30
# Early Stopping Validated
# Best Epoch:    42 / Last Validation Loss: 1.319791
# Early Stopping Validated
# Best Epoch:   134 / Last Validation Loss: 1.251744
# Early Stopping Validated
# Best Epoch:    25 / Last Validation Loss: 1.363798
# Early Stopping Validated
# Best Epoch:    65 / Last Validation Loss: 1.150426
# Early Stopping Validated
# Best Epoch:    39 / Last Validation Loss: 1.181885
# Validation R-squared: 0.444043
# Early Stopping Validated
# Best Epoch:    15 / Last Validation Loss: 2.055358
# # of node: 30
# Test R-squared: 0.379957
# 0.37995673842938515
